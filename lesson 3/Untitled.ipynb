# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

filename='nyc_subway_weather.csv'
subway_df = pd.read_csv(filename)
print subway_df.iloc[1:4]
group_rain=subway_df.groupby('rain')
#print group_rain.groups
mean_group=group_rain.mean()['ENTRIESn_hourly']

print mean_group

# %pylab inline
mean_group.hist()
# Out:
#    UNIT     DATEn     TIMEn  ENTRIESn   EXITSn  ENTRIESn_hourly  \
# 1  R003  05-01-11  04:00:00   4388333  2911002              0.0
# 2  R003  05-01-11  12:00:00   4388333  2911002              0.0
# 3  R003  05-01-11  16:00:00   4388333  2911002              0.0
#
#    EXITSn_hourly             datetime  hour  day_week     ...       pressurei  \
# 1            0.0  2011-05-01 04:00:00     4         6     ...           30.25
# 2            0.0  2011-05-01 12:00:00    12         6     ...           30.28
# 3            0.0  2011-05-01 16:00:00    16         6     ...           30.26
#
#   rain  tempi  wspdi meanprecipi  meanpressurei  meantempi  meanwspdi  \
# 1    0   52.0    3.5         0.0         30.258      55.98       7.86
# 2    0   62.1    6.9         0.0         30.258      55.98       7.86
# 3    0   57.9   15.0         0.0         30.258      55.98       7.86
#
#    weather_lat  weather_lon
# 1    40.700348   -73.887177
# 2    40.700348   -73.887177
# 3    40.700348   -73.887177
#
# [3 rows x 27 columns]
# rain
# 0    1845.539439
# 1    2028.196035
# Name: ENTRIESn_hourly, dtype: float64
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

group_day=subway_df.groupby('day_week')
ridership_day= group_day.mean()['ENTRIESn_hourly']

# %pylab inline
ridership_day.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

group_day=subway_df.groupby('day_week')
ridership_day= group_day.mean()['ENTRIESn_hourly']

# %pylab inline
plt.scatter(subway_df['tempi'],subway_df['ENTRIESn_hourly'] )
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

group_weather=subway_df.groupby(['weather_lat','weather_lon'],as_index=False).mean()

scaled_entries=group_weather['ENTRIESn_hourly']/group_weather['ENTRIESn_hourly'].std()
# %pylab inline
plt.scatter(group_weather['weather_lat'],group_weather['weather_lon'],s=scaled_entries)
# Out:
# Populating the interactive namespace from numpy and matplotlib
